# %% [markdown]
# # Study Case Data Analyst (Dataset for renewable energy systems)
#
#
# ---
#
#
# ###### Source: https://www.kaggle.com/datasets/girumwondemagegn/dataset-for-renewable-energy-systems/data

# %% [markdown]
# ## 1. Introduction:
# Tujuan dari studi kasus ini adalah untuk menganalisis dataset terkait berbagai proyek energi terbarukan. Dataset ini mencakup variabel-variabel seperti type of renewable energy, installed capacity, energy production and consumption, storage capacity, grid integration level, initial investment, funding sources, financial incentives, greenhouse gas (GHG) emission reductions, air pollution reduction index, dan jobs created. Tujuannya adalah untuk memahami hubungan antara variabel-variabel ini dan mengidentifikasi pola atau wawasan signifikan yang dapat menginformasikan pengambilan keputusan dalam proyek energi terbarukan di dunia nyata. Analisis ini mengasumsikan bahwa data tersebut secara akurat mewakili kinerja dan dampak berbagai proyek energi terbarukan.

# %% [markdown]
# ## 2. Problem
#
# Masalah-masalah utama yang diidentifikasi meliputi:
#
# * Efisiensi Proyek Energi Terbarukan: Variabilitas dalam efisiensi sistem penyimpanan energi dapat mengurangi efektivitas proyek secara keseluruhan.
# * Investasi Awal dan Penciptaan Lapangan Kerja: Tidak jelasnya hubungan antara investasi awal dengan penciptaan lapangan kerja dalam konteks energi terbarukan.
# * Pengurangan Emisi GHG: Tidak semua jenis energi terbarukan memberikan pengurangan emisi GHG yang signifikan.
#
# Analisis masalah dilakukan dengan memeriksa korelasi antar variabel dalam dataset, seperti kapasitas terpasang, produksi energi, dan pengurangan emisi GHG.

# %% [markdown]
# ## 3. Solutions
#
# Solusi yang diusulkan untuk mengatasi masalah-masalah tersebut meliputi:
#
# 1.  Optimisasi Sistem Penyimpanan Energi: Memperbaiki efisiensi sistem penyimpanan energi dengan teknologi yang lebih canggih.
# * Pro: Mengurangi kerugian energi, meningkatkan stabilitas jaringan.
# * Con: Memerlukan investasi tambahan untuk teknologi baru.
#
# ---
#
# 2. Peningkatan Investasi dan Insentif: Meningkatkan insentif keuangan untuk proyek energi terbarukan.
# * Pro: Mendorong lebih banyak investasi dan penciptaan lapangan kerja.
# * Con: Memerlukan koordinasi dengan pemerintah dan sektor swasta untuk mendukung kebijakan ini.
#
# ---
#
# 3. Promosi Energi Terbarukan yang Lebih Ramah Lingkungan: Mendorong penggunaan jenis energi terbarukan yang menghasilkan pengurangan emisi GHG yang lebih tinggi.
# * Pro: Mengurangi dampak lingkungan secara signifikan.
# * Con: Membutuhkan pendekatan multi-stakeholder untuk implementasi efektif.

# %% [markdown]
# ## 4. Conclusion
#
# Dalam menyimpulkan, penting untuk mempertimbangkan integrasi yang lebih baik antara teknologi baru dalam sistem penyimpanan energi, peningkatan insentif keuangan, dan promosi energi terbarukan yang lebih ramah lingkungan untuk mengatasi tantangan efisiensi, investasi, dan pengurangan emisi dalam proyek energi terbarukan.

# %% [markdown]
# ## 5. Next Steps
#
# Solusi yang Dipilih: Promosi Energi Terbarukan yang Lebih Ramah Lingkungan
#
# 1. Implementasi: Langkah pertama adalah mengidentifikasi jenis energi terbarukan dengan potensi pengurangan emisi GHG tertinggi melalui analisis data yang mendalam. Selanjutnya, kolaborasi antara pemerintah, sektor swasta, dan masyarakat sipil diperlukan untuk mengembangkan strategi promosi yang efektif dan menyampaikan manfaat energi terbarukan kepada masyarakat secara luas.
#
# 2. Penyelenggaraan: Pemerintah diharapkan untuk memperkenalkan kebijakan insentif yang kuat, seperti subsidi dan regulasi yang mendukung, untuk mendorong adopsi energi terbarukan. Sektor swasta akan memainkan peran penting dalam investasi infrastruktur dan implementasi teknologi energi terbarukan, sementara masyarakat sipil dapat membantu dalam mengedukasi dan mempromosikan keuntungan penggunaan energi terbarukan.
#
# 3. Waktu Pelaksanaan: Rencana implementasi harus dirumuskan dan dilaksanakan dalam jangka waktu enam bulan, dengan pengawasan terus-menerus untuk menilai efektivitas kebijakan yang diterapkan dan mengukur dampaknya terhadap pengurangan emisi GHG.
#
# 4. Siapa yang Perlu Menjalankan: Pemerintah bertanggung jawab atas pengembangan kebijakan insentif dan regulasi, sementara sektor swasta akan mengimplementasikan proyek dan investasi yang diperlukan. Masyarakat sipil berperan dalam mendukung dan mensosialisasikan perubahan perilaku menuju penggunaan energi terbarukan.
#
# 5. Mengapa Pilihan Ini Dipilih: Pilihan untuk mempromosikan energi terbarukan yang lebih ramah lingkungan dipilih karena dampak jangka panjangnya dalam mengurangi ketergantungan pada sumber energi konvensional yang berkontribusi terhadap perubahan iklim global. Hal ini juga akan mendukung keberlanjutan lingkungan dan ekonomi melalui pengurangan emisi GHG dan promosi pertumbuhan sektor energi terbarukan secara holistik.
#
# Dengan langkah-langkah ini, diharapkan promosi energi terbarukan yang lebih ramah lingkungan dapat memberikan manfaat yang berkelanjutan dalam mendukung keberlanjutan lingkungan dan ekonomi.

# %% [markdown]
# ## Data analytics Process Technical

# %% [markdown]
# ### 1. Ask
# Key Business Questions:
#
# 1. Faktor apa yang paling mempengaruhi efisiensi proyek energi terbarukan?
# 2. Bagaimana investasi awal berkorelasi dengan penciptaan lapangan kerja dalam proyek energi terbarukan?
# 3. Jenis energi terbarukan mana yang menghasilkan pengurangan emisi GHG  tertinggi?

# %% [markdown]
# ### 2. Prepare

# %% [markdown]
# #### Data Preparation :
#
# Mengumpulkan atau mengimpor Data: Dapatkan dataset yang berisi variabel-variabel yang relevan.

# %%
import pandas as pd

# Load the dataset
file_path = '/content/energy_dataset_BI.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#   Type_of_Renewable_Energy  Installed_Capacity_MW  Energy_Production_MWh  \
# 0               Geothermal              93.423205            103853.2206
# 1               Geothermal             590.468942            190223.0649
# 2                    Solar             625.951142            266023.4824
# 3                    Solar             779.998728            487039.5296
# 4            Hydroelectric             242.106837            482815.0856
#
#    Energy_Consumption_MWh  Energy_Storage_Capacity_MWh  \
# 0             248708.4892                  2953.248771
# 1             166104.1642                  5305.174042
# 2             424114.6308                  2620.192622
# 3             308337.7316                  1925.250307
# 4             360437.7705                  3948.945383
#
#    Storage_Efficiency_Percentage Grid_Integration_Level  \
# 0                      89.887562     Isolated Microgrid
# 1                      84.403343     Isolated Microgrid
# ...

# %% [markdown]
# Variabel yang digunakan
# 1. Type_of_Renewable_Energy: Kode numerik yang mewakili jenis sumber energi terbarukan (1: Surya, 2: Angin, 3: Hidroelektrik, 4: Geotermal, 5: Biomassa, 6: Pasang Surut, 7: Gelombang).
# 2. Installed_Capacity_MW: Kapasitas terpasang dalam megawatts (MW).
# 3. Energy_Production_MWh: Produksi  energi tahunan dalam megawatt-hours (MWh).
# 4. Energy_Consumption_MWh: Konsumsi energi tahunan dalam megawatt-hours (MWh).
# 5. Energy_Storage_Capacity_MWh: Kapasitas penyimpanan energi dalam megawatt-hours (MWh).
# 6. Storage_Efficiency_Percentage: Efisiensi sistem penyimpanan energi dalam persentase.
# 7. Grid_Integration_Level: Kode numerik yang mewakili tingkat integrasi ke jaringan (1: Terintegrasi Sepenuhnya, 2: Terintegrasi Sebagian, 3: Integrasi Minimal, 4: Mikrogrid Terisolasi).
# 8. Initial_Investment_USD: Biaya investasi awal dalam USD.
# 9. Funding_Sources: Kode numerik yang mewakili sumber pendanaan (1: Pemerintah, 2: Swasta, 3: Kemitraan Publik-Swasta).
# 10. Financial_Incentives_USD: Insentif keuangan dalam USD.
# 11. GHG_Emission_Reduction_tCO2e: Pengurangan emisi gas rumah kaca dalam ton setara CO2 (tCO2e).
# 12. Air_Pollution_Reduction_Index: Indeks pengurangan polusi udara.
# 13. Jobs_Created: jumlah pekerjaan yang tercipta.

# %% [markdown]
# ### 3. Process

# %% [markdown]
# ### Data Cleanning and Preparation
#
# 1. Handle Missing Values: Periksa dan mengatasi titik data yang hilang.

# %%
# Check for missing values in the dataset
missing_values = data.isnull().sum()

# Display the summary of missing values
missing_values

# # If there are missing values, fill those missing values with the mean.
# missing_values = data.fillna(data.mean(), inplace=True)
# Out:
# Type_of_Renewable_Energy         0
# Installed_Capacity_MW            0
# Energy_Production_MWh            0
# Energy_Consumption_MWh           0
# Energy_Storage_Capacity_MWh      0
# Storage_Efficiency_Percentage    0
# Grid_Integration_Level           0
# Initial_Investment_USD           0
# Funding_Sources                  0
# Financial_Incentives_USD         0
# GHG_Emission_Reduction_tCO2e     0
# Air_Pollution_Reduction_Index    0
# Jobs_Created                     0
# dtype: int64

# %% [markdown]
# Diketahui bahwa Dataset ini tidak memiliki *missing value*, langkah berikutnya pastikan tipe data untuk setiap kolom sesuai dan melakukan penyesuaian yang diperlukan.

# %% [markdown]
# 2. Correct Data Types: memastikan semua variabel berada dalam format yang benar.

# %%
# Check the data types of each column
data_types = data.dtypes
data_types
# Out:
# Type_of_Renewable_Energy          object
# Installed_Capacity_MW            float64
# Energy_Production_MWh            float64
# Energy_Consumption_MWh           float64
# Energy_Storage_Capacity_MWh      float64
# Storage_Efficiency_Percentage    float64
# Grid_Integration_Level            object
# Initial_Investment_USD           float64
# Funding_Sources                   object
# Financial_Incentives_USD         float64
# GHG_Emission_Reduction_tCO2e     float64
# Air_Pollution_Reduction_Index    float64
# Jobs_Created                       int64
# dtype: object

# %% [markdown]
# ### 4. Analyze

# %% [markdown]
# #### Exploratory Data Analysis (EDA)

# %% [markdown]
# Statistik Deskriptif: Melakukan perhitungan statistik ringkasan untuk variabel dalam kumpulan data. Proses ini memberikan *insight* tentang distribusi data yang digunakan.

# %%
# Calculate some descriptive statistics
summary_stats = data.describe()
summary_stats
# Out:
#        Installed_Capacity_MW  Energy_Production_MWh  Energy_Consumption_MWh  \
# count           15000.000000           15000.000000            15000.000000
# mean              495.855747          252350.955621           225981.854966
# std               288.212872          144062.915425           129223.677997
# min                 1.091767            1030.103692              584.048006
# 25%               245.475737          128568.875900           115587.428225
# 50%               492.907555          253216.871250           225226.374350
# 75%               742.254682          377083.805575           338656.214700
# max               999.982979          499991.200400           449922.667800
#
#        Energy_Storage_Capacity_MWh  Storage_Efficiency_Percentage  \
# count                 15000.000000                   15000.000000
# mean                   5030.196472                      75.219334
# std                    2894.096326                      14.485289
# ...

# %% [markdown]
# *Insights* Yang didapatkan :
# 1. Type of Renewable Energy: Data mencakup campuran seimbang dari berbagai jenis energi terbarukan.
# 2. Installed Capacity: Bervariasi luas dengan rata-rata sekitar 496 MW.
# 3. Energy Production & Consumption: Menunjukkan variabilitas yang signifikan, menandakan proyek energi yang beragam.
# 4. Energy Storage Capacity: Menunjukkan rentang kapasitas yang luas.
# 5. Storage Efficiency: Umumnya tinggi, dengan rata-rata sekitar 75%.
# 6. Grid Integration Level: Sebagian besar terintegrasi sepenuhnya atau sebagian.
# 7. Initial Investment & Financial Incentives: Jumlah investasi dan insentif menunjukkan variasi yang signifikan.
# 8. GHG Emission Reduction: Proyek-proyek bervariasi dalam dampak mereka.
# 9. Jobs Created: Rentang yang luas, mencerminkan skala proyek yang berbeda.

# %%
import matplotlib.pyplot as plt

# Adjusting the plot for the appropriate number of subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 20))

columns = [
    'Installed_Capacity_MW', 'Energy_Production_MWh', 'Energy_Consumption_MWh',
    'Energy_Storage_Capacity_MWh', 'Storage_Efficiency_Percentage', 'Initial_Investment_USD',
    'Financial_Incentives_USD', 'GHG_Emission_Reduction_tCO2e', 'Air_Pollution_Reduction_Index',
    'Jobs_Created'
]

for ax, column in zip(axes.flatten(), columns):
    data[column].plot.hist(ax=ax, bins=20, title=column)
    ax.set_xlabel(column)

# Remove empty subplots
for i in range(len(columns), len(axes.flatten())):
    fig.delaxes(axes.flatten()[i])

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Convert non-numeric columns to numeric where applicable for better correlation analysis
data['Storage_Efficiency_Percentage'] = pd.to_numeric(data['Storage_Efficiency_Percentage'], errors='coerce')
data['Initial_Investment_USD'] = pd.to_numeric(data['Initial_Investment_USD'], errors='coerce')
data['Jobs_Created'] = pd.to_numeric(data['Jobs_Created'], errors='coerce')
data['GHG_Emission_Reduction_tCO2e'] = pd.to_numeric(data['GHG_Emission_Reduction_tCO2e'], errors='coerce')
data['Energy_Storage_Capacity_MWh'] = pd.to_numeric(data['Energy_Storage_Capacity_MWh'], errors='coerce')

# Convert 'Type_of_Renewable_Energy' to a numerical representation
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Filling missing values before label encoding to avoid errors
data['Type_of_Renewable_Energy'] = data['Type_of_Renewable_Energy'].fillna('Unknown') # Or any suitable placeholder
data['Type_of_Renewable_Energy'] = le.fit_transform(data['Type_of_Renewable_Energy'])

# Recompute the correlation matrix after conversion, excluding non-numeric columns
correlation_matrix_updated = data.select_dtypes(include=['number']).corr() # Select only numeric columns

# Display the updated correlation matrix
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix_updated, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Updated Correlation Matrix of Renewable Energy Project Factors')
plt.show()

# %% [markdown]
# Dari visualisasi data tersebut didapatkan pemahaman Matriks korelasi menunjukkan bahwa sebagian besar variabel memiliki korelasi yang sangat lemah (|r| <= 0.10) antara satu dengan yang lainnya. Hal ini menandakan tidak ada faktor yang dapat diidentifikasi sebagai pengaruh signifikan terhadap efisiensi proyek energi terbarukan berdasarkan korelasi dalam dataset ini.

# %% [markdown]
# Hal tersebut juga yang terjadi antara hubungan investasi awal berkorelasi dengan penciptaan lapangan kerja dalam proyek energi terbarukan

# %%
# Calculate the average GHG emission reduction for each type of renewable energy
average_ghg_reduction = data.groupby('Type_of_Renewable_Energy')['GHG_Emission_Reduction_tCO2e'].mean().sort_values(ascending=False)

# Visualize the average GHG emission reduction for each type of renewable energy
plt.figure(figsize=(12, 6))
sns.barplot(x=average_ghg_reduction.index, y=average_ghg_reduction.values, palette='viridis')
plt.title('Average GHG Emission Reduction by Type of Renewable Energy')
plt.xlabel('Type of Renewable Energy')
plt.ylabel('Average GHG Emission Reduction (tCO2e)')
plt.xticks(rotation=45)
plt.show()

# Display the average GHG emission reduction values
average_ghg_reduction
# Out:
# <ipython-input-14-54d3fe490cd2>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_ghg_reduction.index, y=average_ghg_reduction.values, palette='viridis')
# Type_of_Renewable_Energy
# 0    25645.694359
# 4    25516.901852
# 2    25304.016935
# 5    25282.794316
# 6    25164.216873
# 1    25070.532564
# 3    24666.648378
# Name: GHG_Emission_Reduction_tCO2e, dtype: float64

# %% [markdown]
# Berdasarkan visualisasi tersebut Biomass memiliki pengurangan emisi gas rumah kaca rata-rata tertinggi, diikuti oleh Tidal dan Hydroelectric.
#
# Rata-rata pengurangan emisi gas rumah kaca berdasarkan jenis energi (tCO2e):
# 1. Biomass: 25,645.69
# 2. Tidal: 25,516.90
# 3. Hydroelectric: 25,304.02
# 4. Wave: 25,282.79
# 5. Wind: 25,164.22
# 6. Geothermal: 25,070.53
# 7. Solar: 24,666.65

# %% [markdown]
# ### 5. Share

# %% [markdown]
# ### Communication of Findings:
#
# <!-- Data Visualization Tools: Gunakan alat seperti dashboard untuk menyajikan data secara interaktif.
#
# #### Power BI-->

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Installed_Capacity_MW', y='Energy_Production_MWh', hue='Type_of_Renewable_Energy', size= 'Storage_Efficiency_Percentage',palette='viridis', data=data)
plt.title('Installed_Capacity_MW vs. Energy_Production_MWh')
plt.xlabel('Installed_Capacity_MW')
plt.ylabel('Energy_Production_MWh')
plt.legend(title='Type of Renewable Energy', labels=['Solar', 'Wind', 'Hydroelectric', 'Geothermal', 'Biomass', 'Tidal', 'Wave'])
plt.show()

# %% [markdown]
# Grafik scatterplot ini menunjukkan hubungan antara kapasitas terpasang (MW) dan produksi energi (MWh) dari berbagai jenis energi terbarukan. Setiap titik mewakili satu proyek energi terbarukan, dengan warna yang menunjukkan jenis energi terbarukan (seperti Solar, Angin, Hidroelektrik, Geotermal, Biomassa, Pasang Surut, dan Gelombang), dan ukuran titik menunjukkan efisiensi penyimpanan energi dari proyek tersebut. Grafik ini membantu mengidentifikasi pola dan korelasi antara kapasitas terpasang dan produksi energi, serta bagaimana efisiensi penyimpanan energi bervariasi di antara berbagai jenis energi terbarukan.

# %% [markdown]
# ### 6. Act

# %% [markdown]
# Monitoring: Terus pantau dampak dari tindakan yang dilaksanakan dan sesuaikan strategi sesuai kebutuhan.
